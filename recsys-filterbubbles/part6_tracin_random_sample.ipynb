# %%
import torch
from torch.cuda import random
import torch.nn as nn
import torch.nn.functional as F
import os
import torch.optim as optim
from os import listdir
from os.path import isfile, join
from tracin.tracin_batched import save_tracin_checkpoint, load_tracin_checkpoint,  approximate_tracin_batched
import pandas as pd
from LSTM_clean.model import LSTM
import numpy as np
import re
from statistics import mean
import scipy.stats as stats
import pandas as pd
from sklearn.utils import shuffle
from copy import deepcopy

# %% [markdown]
# # Global Parameters

# %%
OUTPUT_SIZE = 1743

# %% [markdown]
# # Get Most important Checkpoint

# %%
curr_dir = os.getcwd()
path = curr_dir + "/checkpoints_subset/"
checkpoints = []
with os.scandir(path) as listOfEntries:
    for entry in listOfEntries:
        # print all entries that are files
        if entry.is_file():
            checkpoints.append(os.path.join(path,entry.name))
last_checkpoint_epoch = max([re.sub('[^0-9]','', a)[2:] for a in checkpoints])
last_checkpoint = sorted(checkpoints)[-1][:-5] + str(last_checkpoint_epoch) + ".pt"

# %% [markdown]
# # Set Up Devices

# %%
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]='6'

cpu_device = torch.device("cpu")
print("CPU Device is ", cpu_device)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("device is ", device)
# Out:
# CPU Device is  cpu
# device is  cuda

# %% [markdown]
# # Load In Data

# %%
train = np.load(os.path.join(os.getcwd(), "data/twitch_sequence/train.data"), allow_pickle=True)

# %%
model = LSTM(
        input_size=128,
        output_size=OUTPUT_SIZE,
        hidden_dim=64,
        n_layers=1,
        device=cpu_device,
    )

# %%
train_num = len(train)
train_labels = []

for i in range(train_num):
    train_labels.append(train[i][1])
train = [train[i][0] for i in range(train_num)]

# %% [markdown]
# # Subset Data
# Don't need to do if you want to run full experiment (takes a long time to run ~24 hours)

# %%
train, train_labels = shuffle(train, train_labels, random_state=201)
train = train[:3000]
train_labels = train_labels[:3000]

# %% [markdown]
# # Deepcopy to prevent overwriting

# %%
train_copy = deepcopy(train)
train_labels_copy = deepcopy(train_labels)

# %% [markdown]
# # Run Experiments

# %%
si = []
ri =[]

for i in range(20):
    print("___________________________________________________________________________________")
    print(f"Iteration {i}")
    train_random, train_labels_random = shuffle(train_copy, train_labels_copy, random_state=i)
    self_influence = approximate_tracin_batched(LSTM, sources=train_random, targets=train_random, source_labels=train_labels_random, target_labels=train_labels_random, optimizer="SGD", paths=checkpoints, batch_size=2048, num_items=OUTPUT_SIZE, device=device)
    print(f"Self influence is: {self_influence}")
    si.append(self_influence)
    train_random, train_labels_random = shuffle(train_copy, train_labels_copy, random_state=i)
    rs = approximate_tracin_batched(LSTM, sources=train, targets=train_random, source_labels=train_labels, target_labels=train_labels_random, optimizer="SGD", paths=checkpoints, batch_size=2048, num_items=OUTPUT_SIZE, device=device)
    print(f"Random Sample {i} Influence is {rs}")
    ri.append(rs)
# Out:
# ___________________________________________________________________________________
# Iteration 0
# In checkpoint number: 0
# Total time for checkpoint 0 : 24.67806100845337
# In checkpoint number: 1
# Total time for checkpoint 1 : 12.459105730056763
# In checkpoint number: 2
# Total time for checkpoint 2 : 11.063999652862549
# In checkpoint number: 3
# Total time for checkpoint 3 : 12.087036848068237
# In checkpoint number: 4
# Total time for checkpoint 4 : 11.126459836959839
# In checkpoint number: 5
# Total time for checkpoint 5 : 14.599980592727661
# In checkpoint number: 6
# Total time for checkpoint 6 : 10.92798137664795
# Total time for checkpoint 10 : 19.571470737457275
# In checkpoint number: 11
# Total time for checkpoint 11 : 14.449807167053223
# In checkpoint number: 12
# Total time for checkpoint 12 : 14.073602676391602
# In checkpoint number: 13
# Total time for checkpoint 13 : 14.874221801757812
# In checkpoint number: 14
# Total time for checkpoint 14 : 9.448288679122925
# In checkpoint number: 15
# Total time for checkpoint 15 : 14.259100675582886
# In checkpoint number: 16
# Total time for checkpoint 16 : 14.804409980773926
# In checkpoint number: 17
# Total time for checkpoint 17 : 13.878308534622192
# In checkpoint number: 18
# Total time for checkpoint 18 : 16.48513627052307
# In checkpoint number: 19
# Total time for checkpoint 19 : 13.25405216217041
# In checkpoint number: 20
# Total time for checkpoint 20 : 13.242337465286255
# Total time taken is 300.5848665237427
# Self influence is: 0.08289601653814316
# In checkpoint number: 0
# Total time for checkpoint 0 : 1.4141178131103516
# In checkpoint number: 1
# Total time for checkpoint 1 : 1.6256227493286133
# In checkpoint number: 2
# Total time for checkpoint 2 : 1.3595144748687744
# In checkpoint number: 3
# Total time for checkpoint 3 : 1.6997575759887695
# In checkpoint number: 4
# Total time for checkpoint 4 : 2.9019246101379395
# In checkpoint number: 5
# Total time for checkpoint 5 : 4.243244647979736
# In checkpoint number: 6
# Total time for checkpoint 6 : 6.272408723831177
# In checkpoint number: 7
# Total time for checkpoint 7 : 6.016612529754639
# In checkpoint number: 8
# Total time for checkpoint 8 : 1.3535501956939697
# In checkpoint number: 9
# Total time for checkpoint 9 : 5.641200542449951
# In checkpoint number: 10
# Total time for checkpoint 10 : 9.005222082138062
# In checkpoint number: 11
# Total time for checkpoint 11 : 15.335307121276855
# In checkpoint number: 12
# Total time for checkpoint 12 : 14.819474697113037
# In checkpoint number: 13
# Total time for checkpoint 13 : 17.972737789154053
# In checkpoint number: 14
# Total time for checkpoint 14 : 13.105594158172607
# In checkpoint number: 15
# Total time for checkpoint 15 : 13.153375387191772
# In checkpoint number: 16
# Total time for checkpoint 16 : 14.407408475875854
# In checkpoint number: 17
# Total time for checkpoint 17 : 15.84260869026184
# In checkpoint number: 18
# Total time for checkpoint 18 : 15.103067398071289
# In checkpoint number: 19
# Total time for checkpoint 19 : 13.882758140563965
# In checkpoint number: 20
# Total time for checkpoint 20 : 15.546379804611206
# Total time taken is 190.81829190254211
# Random Sample 2 Influence is 0.04751908406615257
# ___________________________________________________________________________________
# Iteration 3
# In checkpoint number: 0
# Total time for checkpoint 0 : 10.493459939956665
# In checkpoint number: 1
# Total time for checkpoint 1 : 15.215709209442139
# In checkpoint number: 2
# Total time for checkpoint 2 : 14.329620122909546
# In checkpoint number: 3
# Total time for checkpoint 3 : 13.177059888839722
# In checkpoint number: 4
# Total time for checkpoint 4 : 15.295119762420654
# In checkpoint number: 5
# Total time for checkpoint 5 : 9.586162805557251
# In checkpoint number: 6
# Total time for checkpoint 6 : 15.195430517196655
# In checkpoint number: 7
# Total time for checkpoint 7 : 10.545149564743042
# In checkpoint number: 8
# Total time for checkpoint 8 : 17.296088695526123
# In checkpoint number: 9
# Total time for checkpoint 9 : 14.339056730270386
# In checkpoint number: 10
# Total time for checkpoint 10 : 14.793529510498047
# In checkpoint number: 11
# Total time for checkpoint 11 : 14.424083948135376
# In checkpoint number: 12
# Total time for checkpoint 12 : 4.460590362548828
# In checkpoint number: 13
# Total time for checkpoint 13 : 2.799649477005005
# In checkpoint number: 14
# Total time for checkpoint 14 : 3.5229403972625732
# In checkpoint number: 15
# Total time for checkpoint 15 : 11.704593658447266
# In checkpoint number: 16
# Total time for checkpoint 16 : 10.041089534759521
# In checkpoint number: 17
# Total time for checkpoint 17 : 14.751399755477905
# In checkpoint number: 18
# Total time for checkpoint 18 : 12.721399307250977
# In checkpoint number: 19
# Total time for checkpoint 19 : 14.67508840560913
# In checkpoint number: 20
# Total time for checkpoint 20 : 16.041136503219604
# Total time taken is 255.5027620792389
# Self influence is: 0.07580509036779404
# In checkpoint number: 0
# Total time for checkpoint 0 : 15.889964818954468
# In checkpoint number: 1
# Total time for checkpoint 1 : 16.689926862716675
# In checkpoint number: 2
# Total time for checkpoint 2 : 15.826846361160278
# In checkpoint number: 3
# Total time for checkpoint 3 : 17.373793363571167
# In checkpoint number: 4
# Total time for checkpoint 4 : 13.550791263580322
# In checkpoint number: 5
# Total time for checkpoint 5 : 13.60815143585205
# In checkpoint number: 6
# Total time for checkpoint 6 : 12.82851243019104
# In checkpoint number: 7
# Total time for checkpoint 7 : 13.396584510803223
# In checkpoint number: 8
# Total time for checkpoint 8 : 4.640136003494263
# In checkpoint number: 9
# Total time for checkpoint 9 : 0.6783690452575684
# In checkpoint number: 10
# Total time for checkpoint 10 : 11.11976146697998
# In checkpoint number: 11
# Total time for checkpoint 11 : 15.281880617141724
# In checkpoint number: 12
# Total time for checkpoint 12 : 9.272913694381714
# In checkpoint number: 13
# Total time for checkpoint 13 : 18.475364923477173
# In checkpoint number: 14
# Total time for checkpoint 14 : 16.138493299484253
# In checkpoint number: 15
# Total time for checkpoint 15 : 14.695570707321167
# In checkpoint number: 16
# Total time for checkpoint 16 : 14.678377628326416
# In checkpoint number: 17
# Total time for checkpoint 17 : 11.706895589828491
# In checkpoint number: 18
# Total time for checkpoint 18 : 13.76607632637024
# In checkpoint number: 19
# Total time for checkpoint 19 : 15.017432928085327
# In checkpoint number: 20
# Total time for checkpoint 20 : 17.304875373840332
# Total time taken is 281.9529447555542
# Random Sample 3 Influence is 0.0457342155277729
# ___________________________________________________________________________________
# Iteration 4
# In checkpoint number: 0
# Total time for checkpoint 0 : 12.17676043510437
# In checkpoint number: 1
# Total time for checkpoint 1 : 16.72167158126831
# In checkpoint number: 2
# Total time for checkpoint 2 : 15.752281904220581
# In checkpoint number: 3
# Total time for checkpoint 3 : 16.004475831985474
# In checkpoint number: 4
# Total time for checkpoint 4 : 16.36176371574402
# In checkpoint number: 5
# Total time for checkpoint 5 : 19.05876636505127
# In checkpoint number: 6
# Total time for checkpoint 6 : 21.422853708267212
# In checkpoint number: 7
# Total time for checkpoint 7 : 19.17582106590271
# In checkpoint number: 8
# Total time for checkpoint 8 : 17.948303937911987
# In checkpoint number: 9
# Total time for checkpoint 9 : 16.707210063934326
# In checkpoint number: 10

# %%
ri = [float(i) for i in ri]
si = [float(j) for j in si]
print("Random influences are \n", ri)
print("Self influences are \n", si)

# %% [markdown]
# # Perform Statistical Tests

# %%
print(f"Difference in population is {stats.ttest_ind(a=np.array(si), b=np.array(ri), equal_var=False)}")
